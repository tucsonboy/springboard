# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'C:\mia_data2.csv')

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  YEAR  MONTH  DAY_OF_WEEK  OP_CARRIER_FL_NUM  \
# 0             0         459  2010      5          6.0                674
# 1             1         460  2010      5          7.0                674
# 2             2         461  2010      5          1.0                674
# 3             3         462  2010      5          2.0                674
# 4             4         463  2010      5          3.0                674
#
#   ORIGIN DEST  CRS_DEP_TIME  DEP_TIME  ...  CRS_ELAPSED_TIME  \
# 0    STT  MIA          1535    1519.0  ...             185.0
# 1    STT  MIA          1535    1550.0  ...             185.0
# 2    STT  MIA          1535    1550.0  ...             185.0
# 3    STT  MIA          1535    1533.0  ...             185.0
# 4    STT  MIA          1535    1557.0  ...             185.0
#
#    ACTUAL_ELAPSED_TIME  CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  \
# 0                196.0            0.0            0.0        0.0
# ...

# %%
df.WHY_DELAY.unique()
# Out:
# array(['0', 'nas', 'carrier', 'weather', 'late aircraft', 'security'],
#       dtype=object)

# %%
df.WHY_DELAY.value_counts()
# Out:
# 0                573448
# carrier           84593
# nas               46935
# weather           17749
# late aircraft     13627
# security            300
# Name: WHY_DELAY, dtype: int64

# %%
df1 = df[df.WHY_DELAY != '0']

# %%
df1.head()
# Out:
#     Unnamed: 0.1  Unnamed: 0  YEAR  MONTH  DAY_OF_WEEK  OP_CARRIER_FL_NUM  \
# 6              6         465  2010      5          5.0                674
# 8              8         467  2010      5          7.0                674
# 15            15         474  2010      5          7.0                674
# 16            16         475  2010      5          1.0                674
# 17            17         476  2010      5          2.0                674
#
#    ORIGIN DEST  CRS_DEP_TIME  DEP_TIME  ...  CRS_ELAPSED_TIME  \
# 6     STT  MIA          1535    1649.0  ...             185.0
# 8     STT  MIA          1535    1608.0  ...             185.0
# 15    STT  MIA          1535    1711.0  ...             185.0
# 16    STT  MIA          1535    1703.0  ...             185.0
# 17    STT  MIA          1535    1528.0  ...             185.0
#
#     ACTUAL_ELAPSED_TIME  CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  \
# 6                 194.0            0.0            0.0        9.0
# ...

# %%
df1.WHY_DELAY.value_counts()
# Out:
# carrier          84593
# nas              46935
# weather          17749
# late aircraft    13627
# security           300
# Name: WHY_DELAY, dtype: int64

# %%
df1.WHY_DELAY.value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='WHY_DELAY'>

# %%
df1.unique()
# Out:
# array(['0', 'nas', 'carrier', 'weather', 'late aircraft', 'security'],
#       dtype=object)
